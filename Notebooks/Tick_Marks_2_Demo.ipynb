# %% [markdown]
# # Tick Marks V2

# %% [markdown]
# ## Import from KiCad library

# %%
import sys
sys.path.append('../src')
# from dial_scale import calc_polygon_scale
# from dial_scale import create_lin_dial_scale_grid
# from dial_scale import create_log_dial_scale_grid
# from dial_scale import create_handle
# from dial_scale import linspace
# from dial_scale import logspace
# from dial_scale import calc_rad
# from dial_scale import log_to_file

# from dial_scale import calc_spiral
# from dial_scale import calc_splitted_poly

from dial_scale import calc_fullrange_minor_tick_makrs
from dial_scale import calc_major_tick_marks
from dial_scale import calc_sep_minor_tick_marks

# from dial_scale import _r_of_phi
# from dial_scale import _find_intersection
# from dial_scale import _calculate_error
# import math

# %% [markdown]
# ## Import special for Jupyter Notebook plotting

# %%
from plotter import plot_line_arrays
from plotter import plot_poly_x_y
from plotter import plot_multi_poly_x_y
from plotter import xy_array_to_xANDyArray

# %% [markdown]
# ## Examples

# %%
start_angle = -150
stop_angle = 150

num_major_ticks = 10
num_minor_ticks = 3
skip_major_pos= True

start_inner_radius = 5
stop_inner_radius = 5
start_outer_radius = 7
stop_outer_radius = 10

major_tick_marks = calc_major_tick_marks(start_inner_radius = start_inner_radius,
                                         stop_inner_radius = stop_inner_radius,
                                         start_outer_radius=start_outer_radius,
                                         stop_outer_radius=stop_outer_radius,
                                         start_angle= start_angle,
                                         stop_angle=stop_angle,
                                         num_major_ticks=num_major_ticks)

start_inner_minor_radius= 5
stop_inner_minor_radius = 5
start_outer_minor_radius = 6
stop_outer_minor_radius = 9
minor_tick_marks = calc_fullrange_minor_tick_makrs(start_inner_radius = start_inner_minor_radius,
                                                  stop_inner_radius = stop_inner_minor_radius,
                                                  start_outer_radius=start_outer_minor_radius,
                                                  stop_outer_radius=stop_outer_minor_radius,
                                                  start_angle= start_angle,
                                                  stop_angle=stop_angle,
                                                  num_major_ticks=num_major_ticks,
                                                  num_minor_ticks=num_minor_ticks,
                                                  skip_major_pos=skip_major_pos
                                                  )
# print(len(minor_tick_marks), len(major_tick_marks))
plot_line_arrays([minor_tick_marks, major_tick_marks], show_data=False)

# %%
start_inner_radius: float = 5
stop_inner_radius: float = 5
start_outer_radius: float = 5.5
stop_outer_radius: float = 8

start_angle: float = -135
stop_angle: float = 135

num_major_ticks: int = 10
num_minor_ticks: int = 8
face_counts: int = 30
skip_major_pos: bool = True
distance = 0.2
major_tick_marks = calc_major_tick_marks(start_inner_radius = start_inner_radius,
                                         stop_inner_radius = stop_inner_radius,
                                         start_outer_radius=start_outer_radius,
                                         stop_outer_radius=stop_outer_radius,
                                         start_angle= start_angle,
                                         stop_angle=stop_angle,
                                         num_major_ticks=num_major_ticks)
start_inner_minor_radius= 5
stop_inner_minor_radius = 5
start_outer_minor_radius = 5.3
stop_outer_minor_radius = 7

minor_tick_marks = calc_sep_minor_tick_marks(start_inner_radius = start_inner_minor_radius,
                                             stop_inner_radius = stop_inner_minor_radius,
                                             start_outer_radius=start_outer_minor_radius,
                                             stop_outer_radius=stop_outer_minor_radius,
                                             start_angle= start_angle,
                                             stop_angle=stop_angle,
                                             num_major_ticks=num_major_ticks,
                                             num_minor_ticks=num_minor_ticks,
                                             skip_major_pos=skip_major_pos
                                             )


print(len(minor_tick_marks), len(major_tick_marks))
plot_line_arrays([minor_tick_marks, major_tick_marks], show_data=False)
# plot_line_arrays([minor_tick_marks], show_data=False)
# Out:
# 72 10

# %%
start_inner_radius: float = 5
stop_inner_radius: float = 5
start_outer_radius: float = 5.5
stop_outer_radius: float = 8

start_angle: float = -135
stop_angle: float = 135

num_major_ticks: int = 10
num_minor_ticks: int = 8
face_counts: int = 30
skip_major_pos: bool = True
distance = 0.2
major_tick_marks = calc_major_tick_marks(start_inner_radius = start_inner_radius,
                                         stop_inner_radius = stop_inner_radius,
                                         start_outer_radius=start_outer_radius,
                                         stop_outer_radius=stop_outer_radius,
                                         start_angle= start_angle,
                                         stop_angle=stop_angle,
                                         num_major_ticks=num_major_ticks)
start_inner_minor_radius= 5
stop_inner_minor_radius = 7
start_outer_minor_radius = 7
stop_outer_minor_radius = 5

minor_tick_marks = calc_sep_minor_tick_marks(start_inner_radius = start_inner_minor_radius,
                                             stop_inner_radius = stop_inner_minor_radius,
                                             start_outer_radius=start_outer_minor_radius,
                                             stop_outer_radius=stop_outer_minor_radius,
                                             start_angle= start_angle,
                                             stop_angle=stop_angle,
                                             num_major_ticks=num_major_ticks,
                                             num_minor_ticks=num_minor_ticks,
                                             skip_major_pos=skip_major_pos
                                             )


print(len(minor_tick_marks), len(major_tick_marks))
plot_line_arrays([minor_tick_marks, major_tick_marks], show_data=False)
# plot_line_arrays([minor_tick_marks], show_data=False)
# Out:
# 72 10
